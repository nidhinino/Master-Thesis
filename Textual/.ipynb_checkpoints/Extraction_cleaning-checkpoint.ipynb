# %%
import PyPDF2
import pdfplumber
import pandas as pd
import re
import os
import time
import psutil
import threading
import textract


def measure_extraction_performance_parallel(extraction_func, pdf_path):
    """
    Measure performance metrics for a given extraction method in parallel.
    
    Args:
        extraction_func (callable): Function to extract text.
        pdf_path (str): Path to PDF file.
    
    Returns:
        dict: Performance metrics for the extraction method.
    """
    metrics = {
        'extraction_time': 0,
        'memory_usage': 0,
        'cpu_usage': 0,
        'extracted_text_length': 0
    }
    
    # Function to monitor CPU and memory usage
    def monitor_performance():
        process = psutil.Process()
        while not stop_event.is_set():
            metrics['memory_usage'] = max(metrics['memory_usage'], process.memory_info().rss / (1024 * 1024))
            metrics['cpu_usage'] = max(metrics['cpu_usage'], psutil.cpu_percent(interval=0.1))
            time.sleep(0.1)

    # Start monitoring in a separate thread
    stop_event = threading.Event()
    monitor_thread = threading.Thread(target=monitor_performance)
    monitor_thread.start()

    # Perform the extraction
    start_time = time.time()
    extracted_text = extraction_func(pdf_path)
    metrics['extraction_time'] = time.time() - start_time
    metrics['extracted_text_length'] = len(extracted_text)

    # Stop monitoring and wait for the thread to finish
    stop_event.set()
    monitor_thread.join()

    return metrics


def extract_with_pypdf2(pdf_path):
    with open(pdf_path, 'rb') as pdf_file:
        reader = PyPDF2.PdfReader(pdf_file)
        return "".join(page.extract_text() for page in reader.pages)


def extract_with_pdfplumber(pdf_path):
    with pdfplumber.open(pdf_path) as pdf:
        return "".join(page.extract_text() for page in pdf.pages)


def extract_text_from_pdf(pdf_path):
    try:
        return textract.process(pdf_path).decode('utf-8')
    except Exception as e:
        print(f"Error extracting text from {pdf_path}: {e}")
        return ""


def clean_text(text, filename, method):
    """
    Clean extracted text and save to file
    
    Args:
        text (str): Raw extracted text
        filename (str): Name of the source file
        method (str): Extraction method used
    
    Returns:
        str: Cleaned text
    """
    # Remove extra whitespaces
    text = re.sub(r'\s+', ' ', text).strip()
    
    # Remove page numbers, headers, footers
    text = re.sub(r'\d+\s*[\|\-]\s*\d+', '', text)
    
    # Ensure method directory exists
    os.makedirs(method, exist_ok=True)
    
    # Write cleaned text to file
    f = open(os.path.join(method, filename[:-4] + ".txt"), "a", encoding="utf-8")
    f.write(text)
    f.close()
    
    return text


def process_pdf_directory(directory_path, performance_file="extraction_performance.csv"):
    """
    Process all PDFs in a directory with performance tracking
    
    Args:
        directory_path (str): Path to directory with PDFs
        performance_file (str): Path to save performance metrics
    
    Returns:
        pd.DataFrame: DataFrame with performance metrics
    """
    performance_results = []
    extraction_methods = [
        ("PyPDF2", extract_with_pypdf2),
        ("PDFPlumber", extract_with_pdfplumber),
        ("Textract", extract_text_from_pdf)
    ]

    for filename in os.listdir(directory_path):
        if filename.endswith('.pdf'):
            pdf_path = os.path.join(directory_path, filename)
            
            for method_name, extraction_func in extraction_methods:
                try:
                    # Measure performance
                    performance_metrics = measure_extraction_performance_parallel(extraction_func, pdf_path)
                    
                    # Extract and clean text
                    raw_text = extraction_func(pdf_path)
                    clean_text(raw_text, filename, method=f"./{method_name.lower()}/")
                    
                    # Append performance results
                    performance_results.append({
                        'Filename': filename,
                        'Extraction Method': method_name,
                        **performance_metrics
                    })
                    print(f'{filename} processed successfully with {method_name}')
                except Exception as e:
                    print(f"Error processing {filename} with {method_name}: {e}")

    # Save performance metrics
    performance_df = pd.DataFrame(performance_results)
    performance_df.to_csv(performance_file, index=False)
    print(f"Performance metrics saved to {performance_file}")
    
    return performance_df

# Example usage
pdf_directory = "../ESG REPORTS"
performance_metrics = process_pdf_directory(pdf_directory)
print(performance_metrics)
# Out:
# Error processing KionGroup_ESG_EN_2018.pdf with PyPDF2: [Errno 2] No such file or directory: '../ESG REPORTS/KionGroup_ESG_EN_2018.pdf'
# Error processing KionGroup_ESG_EN_2018.pdf with PDFPlumber: [Errno 2] No such file or directory: '../ESG REPORTS/KionGroup_ESG_EN_2018.pdf'
# Error extracting text from ../ESG REPORTS/KionGroup_ESG_EN_2018.pdf: The file "../ESG REPORTS/KionGroup_ESG_EN_2018.pdf" can not be found.
# Is this the right path/to/file/you/want/to/extract.pdf?
# Error extracting text from ../ESG REPORTS/KionGroup_ESG_EN_2018.pdf: The file "../ESG REPORTS/KionGroup_ESG_EN_2018.pdf" can not be found.
# Is this the right path/to/file/you/want/to/extract.pdf?
# Error processing KionGroup_ESG_EN_2022.pdf with PyPDF2: [Errno 2] No such file or directory: '../ESG REPORTS/KionGroup_ESG_EN_2022.pdf'
# Error processing KionGroup_ESG_EN_2022.pdf with PDFPlumber: [Errno 2] No such file or directory: '../ESG REPORTS/KionGroup_ESG_EN_2022.pdf'
# Error extracting text from ../ESG REPORTS/KionGroup_ESG_EN_2022.pdf: The file "../ESG REPORTS/KionGroup_ESG_EN_2022.pdf" can not be found.
# Is this the right path/to/file/you/want/to/extract.pdf?
# Error extracting text from ../ESG REPORTS/KionGroup_ESG_EN_2022.pdf: The file "../ESG REPORTS/KionGroup_ESG_EN_2022.pdf" can not be found.
# Is this the right path/to/file/you/want/to/extract.pdf?
# Error processing KionGroup_ESG_EN_2017.pdf with PyPDF2: [Errno 2] No such file or directory: '../ESG REPORTS/KionGroup_ESG_EN_2017.pdf'
# Error processing KionGroup_ESG_EN_2017.pdf with PDFPlumber: [Errno 2] No such file or directory: '../ESG REPORTS/KionGroup_ESG_EN_2017.pdf'
# Error extracting text from ../ESG REPORTS/KionGroup_ESG_EN_2017.pdf: The file "../ESG REPORTS/KionGroup_ESG_EN_2017.pdf" can not be found.
# Is this the right path/to/file/you/want/to/extract.pdf?
# Error extracting text from ../ESG REPORTS/KionGroup_ESG_EN_2017.pdf: The file "../ESG REPORTS/KionGroup_ESG_EN_2017.pdf" can not be found.
# Is this the right path/to/file/you/want/to/extract.pdf?
# ignore '/Perms' verify failed
# ignore '/Perms' verify failed
# Data-loss while decompressing corrupted data
# Data-loss while decompressing corrupted data
# Data-loss while decompressing corrupted data
# Data-loss while decompressing corrupted data
# Data-loss while decompressing corrupted data
# Data-loss while decompressing corrupted data
# Data-loss while decompressing corrupted data
# Data-loss while decompressing corrupted data
# Error processing GEAGroup_ESG_EN_2023.pdf with PDFPlumber: Invalid dictionary construct: [/'FB', /b'tru', /b'e', /'SW', /'N']
# Error processing Evonik_ESG_EN_2019.pdf with PDFPlumber: Invalid dictionary construct: [/'H', /b'tr', /b'ue', /'S', /'Hide', /'T', b'Hauptinhalt 63', /'Type', /'Action']
# Error processing KionGroup_ESG_EN_2023.pdf with PyPDF2: [Errno 2] No such file or directory: '../ESG REPORTS/KionGroup_ESG_EN_2023.pdf'
# Error processing KionGroup_ESG_EN_2023.pdf with PDFPlumber: [Errno 2] No such file or directory: '../ESG REPORTS/KionGroup_ESG_EN_2023.pdf'
# Error extracting text from ../ESG REPORTS/KionGroup_ESG_EN_2023.pdf: The file "../ESG REPORTS/KionGroup_ESG_EN_2023.pdf" can not be found.
# Is this the right path/to/file/you/want/to/extract.pdf?
# Error extracting text from ../ESG REPORTS/KionGroup_ESG_EN_2023.pdf: The file "../ESG REPORTS/KionGroup_ESG_EN_2023.pdf" can not be found.
# Is this the right path/to/file/you/want/to/extract.pdf?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 153
#     151 # Example usage
#     152 pdf_directory = "../ESG REPORTS"
# --> 153 performance_metrics = process_pdf_directory(pdf_directory)
#     154 print(performance_metrics)
#
# Cell In[1], line 132, in process_pdf_directory(directory_path, performance_file)
#     129 performance_metrics = measure_extraction_performance_parallel(extraction_func, pdf_path)
#     131 # Extract and clean text
# --> 132 raw_text = extraction_func(pdf_path)
#     133 clean_text(raw_text, filename, method=f"./{method_name.lower()}/")
#     135 # Append performance results
#
# Cell In[1], line 59, in extract_with_pypdf2(pdf_path)
#      57 with open(pdf_path, 'rb') as pdf_file:
#      58     reader = PyPDF2.PdfReader(pdf_file)
# ---> 59     return "".join(page.extract_text() for page in reader.pages)
#
# Cell In[1], line 59, in <genexpr>(.0)
#      57 with open(pdf_path, 'rb') as pdf_file:
#      58     reader = PyPDF2.PdfReader(pdf_file)
# ---> 59     return "".join(page.extract_text() for page in reader.pages)
#
# File ~/Documents/Master Thesis/venv/lib/python3.12/site-packages/PyPDF2/_page.py:1837, in PageObject.extract_text(self, Tj_sep, TJ_sep, orientations, space_width, visitor_operand_before, visitor_operand_after, visitor_text, *args)
#    1834 if isinstance(orientations, int):
#    1835     orientations = (orientations,)
# -> 1837 return self._extract_text(
#    1838     self,
#    1839     self.pdf,
#    1840     orientations,
#    1841     space_width,
#    1842     PG.CONTENTS,
#    1843     visitor_operand_before,
#    1844     visitor_operand_after,
#    1845     visitor_text,
#    1846 )
#
# File ~/Documents/Master Thesis/venv/lib/python3.12/site-packages/PyPDF2/_page.py:1724, in PageObject._extract_text(self, obj, pdf, orientations, space_width, content_key, visitor_operand_before, visitor_operand_after, visitor_text)
#    1722 try:
#    1723     xobj = resources_dict["/XObject"]
# -> 1724     if xobj[operands[0]]["/Subtype"] != "/Image":  # type: ignore
#    1725         # output += text
#    1726         text = self.extract_xform_text(
#    1727             xobj[operands[0]],  # type: ignore
#    1728             orientations,
#    (...)
#    1732             visitor_text,
#    1733         )
#    1734         output += text
#
# File ~/Documents/Master Thesis/venv/lib/python3.12/site-packages/PyPDF2/generic/_data_structures.py:150, in DictionaryObject.__getitem__(self, key)
#     149 def __getitem__(self, key: Any) -> PdfObject:
# --> 150     return dict.__getitem__(self, key).get_object()
#
# File ~/Documents/Master Thesis/venv/lib/python3.12/site-packages/PyPDF2/generic/_base.py:164, in IndirectObject.get_object(self)
#     163 def get_object(self) -> Optional[PdfObject]:
# --> 164     obj = self.pdf.get_object(self)
#     165     if obj is None:
#     166         return None
#
# File ~/Documents/Master Thesis/venv/lib/python3.12/site-packages/PyPDF2/_reader.py:1256, in PdfReader.get_object(self, indirect_reference)
#    1254 if self.strict:
#    1255     assert generation == indirect_reference.generation
# -> 1256 retval = read_object(self.stream, self)  # type: ignore
#    1258 # override encryption is used for the /Encrypt dictionary
#    1259 if not self._override_encryption and self._encryption is not None:
#    1260     # if we don't have the encryption key:
#
# File ~/Documents/Master Thesis/venv/lib/python3.12/site-packages/PyPDF2/generic/_data_structures.py:841, in read_object(stream, pdf, forced_encoding)
#     838 stream.seek(-2, 1)  # reset to start
#     840 if peek == b"<<":
# --> 841     return DictionaryObject.read_from_stream(stream, pdf, forced_encoding)
#     842 else:
#     843     return read_hex_string_from_stream(stream, forced_encoding)
#
# File ~/Documents/Master Thesis/venv/lib/python3.12/site-packages/PyPDF2/generic/_data_structures.py:270, in DictionaryObject.read_from_stream(stream, pdf, forced_encoding)
#     268     tok = read_non_whitespace(stream)
#     269     stream.seek(-1, 1)
# --> 270     value = read_object(stream, pdf, forced_encoding)
#     271 except Exception as exc:
#     272     if pdf is not None and pdf.strict:
#
# File ~/Documents/Master Thesis/venv/lib/python3.12/site-packages/PyPDF2/generic/_data_structures.py:834, in read_object(stream, pdf, forced_encoding)
#     832 stream.seek(-1, 1)  # reset to start
#     833 if tok == b"/":
# --> 834     return NameObject.read_from_stream(stream, pdf)
#     835 elif tok == b"<":
#     836     # hexadecimal string OR dictionary
#     837     peek = stream.read(2)
#
# File ~/Documents/Master Thesis/venv/lib/python3.12/site-packages/PyPDF2/generic/_base.py:466, in NameObject.read_from_stream(stream, pdf)
#     462 name += read_until_regex(stream, NameObject.delimiter_pattern, ignore_eof=True)
#     463 try:
#     464     # Name objects should represent irregular characters
#     465     # with a '#' followed by the symbol's hex number
# --> 466     name = NameObject.unnumber(name)
#     467     for enc in ("utf-8", "gbk"):
#     468         try:
#
# File ~/Documents/Master Thesis/venv/lib/python3.12/site-packages/PyPDF2/generic/_base.py:444, in NameObject.unnumber(sin)
#     441                 out += c.encode("utf-8")
#     442     return out
# --> 444 @staticmethod
#     445 def unnumber(sin: bytes) -> bytes:
#     446     i = sin.find(b"#", 0)
#     447     while i >= 0:
#
# KeyboardInterrupt:
